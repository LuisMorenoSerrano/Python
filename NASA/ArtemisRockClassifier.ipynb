# %%
# Init program
print("Artemis Rover Rock Scanner Starting")

# Initialize variables
basalt = 0
breccia = 0
highland = 0
regolith = 0
unknown = 0
rockList = []
# Out:
# Artemis Rover Rock Scanner Starting

# %%
# Create external text file with rocks
strPath = "rocks.txt"
fileObject = open(strPath, "w")
fileObject.writelines(["Reading Rocks\n","basalt\n","breccia\n","highland\n","regolith\n","highland\n","breccia\n","highland\n","regolith\n","regolith\n","basalt\n","highland\n","basalt\n","breccia\n","breccia\n","regolith\n","breccia\n","highland\n","highland\n","breccia\n","basalt\n"])
fileObject.close()

# %%
# Read rocks data from external text file
strPath = "rocks.txt"
fileObject = open(strPath)

header = fileObject.readline()
rockList = fileObject.readlines()

fileObject.close()

print(header)

for rock in rockList:
    print(rock)
# Out:
# Reading Rocks
#
# basalt
#
# breccia
#
# highland
#
# regolith
#
# highland
#
# breccia
#
# highland
#
# regolith
#
# regolith
#
# basalt
#
# highland
#
# basalt
#
# breccia
#
# breccia
#
# regolith
#
# breccia
#
# highland
#
# highland
#
# breccia
#
# basalt

# %%
def countMoonRocks(rockToID):
    global basalt
    global breccia
    global highland
    global regolith
    global unknown

    rockToID = rockToID.lower()

    if ("basalt" in rockToID):
        print("Found a basalt\n")
        basalt += 1
    elif ("breccia" in rockToID):
        print("Found a breccia\n")
        breccia += 1
    elif ("highland" in rockToID):
        print("Found a highland\n")
        highland += 1
    elif ("regolith" in rockToID):
        print("Found a regolith\n")
        regolith += 1
    else:
        print("Found an unknown rock: {}\n", rockToID)
        unknown += 1

    return

# %%
for rock in rockList:
    countMoonRocks(rock)
# Out:
# Found a basalt
#
# Found a breccia
#
# Found a highland
#
# Found a regolith
#
# Found a highland
#
# Found a breccia
#
# Found a highland
#
# Found a regolith
#
# Found a regolith
#
# Found a basalt
#
# Found a highland
#
# Found a basalt
#
# Found a breccia
#
# Found a breccia
#
# Found a regolith
#
# Found a breccia
#
# Found a highland
#
# Found a highland
#
# Found a breccia
#
# Found a basalt

# %%
print("Number of Basalt..: ", basalt)
print("Number of Breccia.: ", breccia)
print("Number of Highland: ", highland)
print("Number of Regolith: ", regolith)

print("The max number of one type of rock found was....:",
      max(basalt, breccia, highland,regolith))
print("The minimum number of one type of rock found was:",
      min(basalt, breccia, highland, regolith))
# Out:
# Number of Basalt..:  4
# Number of Breccia.:  6
# Number of Highland:  6
# Number of Regolith:  4
# The max number of one type of rock found was....: 6
# The minimum number of one type of rock found was: 4
